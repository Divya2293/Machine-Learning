# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya2293/Machine-Learning/blob/main/BYTS_Regularization_(L1_%26L2)_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Regularization
# to avoid overfitting
# types:
#
# *   Ridge Regression(L2)
# *   Lasso Regression(L1)

# %% [markdown]
# Ridge Regression
# is a type of
# L2 regularization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lasso Regression is a type of
# L1 regularization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Why Lasso over Ridge?
# Lasso regression takes a diamond shape in the plot for the constrained region, each time the elliptical regions intersect with these corners, at **least one of the coefficients becomes zero**. This is impossible in the ridge regression model as it forms a circular shape and therefore values can be **shrunk close to zero, but never equal to zero.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([2.1,3.8,6.5,9.2,11.3])

# %%
#c_  => columnstack
x_b=np.c_[np.ones((x.shape[0],1)),x]
x_b
# Out:
# array([[1., 1.],
#        [1., 2.],
#        [1., 3.],
#        [1., 4.],
#        [1., 5.]])

# %%
alpha_ridge=1.0
alpha_lasso=0.1
num_iterations=1000
learning_rate=0.01

# %%
def lasso_reg(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  weights=np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(weights)
    gradient=(x.T.dot(y_pred-y) + alpha*np.sign(weights))/m
    weights-=learning_rate*gradient
  return weights

# %%
def ridge_reg(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  weights=np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(weights)
    gradient=(x.T.dot(y_pred-y) + alpha*weights)/m
    weights-=learning_rate*gradient
  return weights

# %%
lasso=lasso_reg(x_b,y,alpha_lasso,num_iterations,learning_rate)
ridge=ridge_reg(x_b,y,alpha_ridge,num_iterations,learning_rate)

# %%
print(lasso)
print(ridge)
# Out:
# [-0.27352287  2.29942818]
# [0.05700254 2.17211411]

# %%
plt.scatter(x,y,label='Data')
plt.plot(x,x_b.dot(ridge),label=f'Ridge (L2) Regression',color='red')
plt.plot(x,x_b.dot(lasso),label=f'Lasso (L1) Regression',color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
