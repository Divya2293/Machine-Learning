# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya2293/Calcbot/blob/main/BYTS_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas for data manipulation and analysis
# It offers data structures and operations for manipulating numericals and time series.
# another type like pandas is polars

# %% [markdown]
# ##Series
# 1D array in sequence
# ##DataFrame
# 2D -rows and columns

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,4])
print(a)
print(type(a))
# Out:
# [1 2 3 4 4]
# <class 'numpy.ndarray'>

# %% [markdown]
# #Series

# %%
s=pd.Series(a)
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s[2]
# Out:
# 3

# %% [markdown]
# ##Drop

# %%
#drops the elements without any change in the index by default
q=s.drop(2)
print(s)
print(q)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# dtype: int64
# 0    1
# 1    2
# 3    4
# 4    4
# dtype: int64

# %%
r=s.drop(3,inplace=False)
print(r)
# Out:
# 0    1
# 1    2
# 4    4
# dtype: int64

# %%
print(s.iloc())
print(s.loc(0))

# %%
s2=pd.Series([10,11,12,13],index=['a','a','c','d'])
print(s2)
# Out:
# a    10
# a    11
# c    12
# d    13
# dtype: int64

# %% [markdown]
# loc[]-   for explicit index given\
# iloc[]-  for implicit indexing

# %%
print(s2.loc['a'])
print(s2.iloc[2])
print(s2.iloc[3])
# Out:
# a    10
# a    11
# dtype: int64
# 12
# 13

# %%
s1=pd.Series([6,6,7,8,9])
d1=pd.DataFrame(s1,s)
print(d1)
# Out:
#    0
# 1  6
# 2  7
# 4  9
# 4  9

# %% [markdown]
# #NotANumber(NaN)
# None  ,' '  ,''  , -  ,     ?      ,  Nil

# %% [markdown]
# #DataFrame

# %%
data=[['Alexa',10,'2000'],['Bob',None,None],['Clarie',None,'2020']]
print(data)
# Out:
# [['Alexa', 10, '2000'], ['Bob', None, None], ['Clarie', None, '2020']]

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#         0     1     2
# 0   Alexa  10.0  2000
# 1     Bob   NaN  None
# 2  Clarie   NaN  2020

# %%
columns=['Name','Age','Year']

df2=pd.DataFrame(data,columns=columns)
df2
# Out:
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob   NaN  None
# 2  Clarie   NaN  2020

# %%
#Slicing through rows of the dataframe
print(df2[1:2])
# Out:
#   Name  Age  Year
# 1  Bob  NaN  None

# %%
print(df2['Age'])
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
#to access Alexa
print(df2['Name'][0])#or
print(df2.loc[0,'Name'])#or
print(df2.iloc[0,0])
# Out:
# Alexa
# Alexa
# Alexa

# %%
print(df2.head(2))
print("-----------------------")
print(df2.tail(1))
print("-----------------------")
print(df2.tail(-1))
# Out:
#     Name   Age  Year
# 0  Alexa  10.0  2000
# 1    Bob   NaN  None
# -----------------------
#      Name  Age  Year
# 2  Clarie  NaN  2020
# -----------------------
#      Name  Age  Year
# 1     Bob  NaN  None
# 2  Clarie  NaN  2020

# %%
df2.tail(-2)
# Out:
#      Name  Age  Year
# 2  Clarie  NaN  2020

# %%
df2.isnull()
# Out:
#     Name    Age   Year
# 0  False  False  False
# 1  False   True   True
# 2  False   True  False

# %%
 df2.isnull().sum()
# Out:
# Name    0
# Age     2
# Year    1
# dtype: int64

# %%
s1.plot()
# Out:
# <Axes: >

# %%
s1.hist(bins=5)
# Out:
# <Axes: >

# %%
print(type(s1))
s1=s1.to_numpy()
print(type(s1))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>

# %%
df3=df2.dropna()
df3
# Out:
#     Name   Age  Year
# 0  Alexa  10.0  2000

# %%
df4=df2.fillna(method='ffill')
print(df4)
# Out:
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob  10.0  2000
# 2  Clarie  10.0  2020

# %%
print(df2.fillna(0))
# Out:
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob   0.0     0
# 2  Clarie   0.0  2020

# %%
df5=df2.drop(['Age'],axis=1,inplace=False)  ##search for the puprose of inplace......
print(df5)
print(df2)
# Out:
#      Name  Year
# 0   Alexa  2000
# 1     Bob  None
# 2  Clarie  2020
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob   NaN  None
# 2  Clarie   NaN  2020

# %%
df2.drop([0,2])
# Out:
#   Name  Age  Year
# 1  Bob  NaN  None

# %%
a=np.array([10,12,13,44,56])
print(a)
# Out:
# [10 12 13 44 56]

# %%
a>40
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>44]
# Out:
# array([56])

# %%
a[a%2!=0]
# Out:
# array([13])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       1 non-null      float64
#  2   2       2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#           1
# count   1.0
# mean   10.0
# std     NaN
# min    10.0
# 25%    10.0
# 50%    10.0
# 75%    10.0
# max    10.0

# %%
df.describe()
# Out:
#           1
# count   1.0
# mean   10.0
# std     NaN
# min    10.0
# 25%    10.0
# 50%    10.0
# 75%    10.0
# max    10.0

# %%
df.describe(include='all')
# Out:
#             0     1     2
# count       3   1.0     2
# unique      3   NaN     2
# top     Alexa   NaN  2000
# freq        1   NaN     1
# mean      NaN  10.0   NaN
# std       NaN   NaN   NaN
# min       NaN  10.0   NaN
# 25%       NaN  10.0   NaN
# 50%       NaN  10.0   NaN
# 75%       NaN  10.0   NaN
# max       NaN  10.0   NaN

# %%
print(df2['Name'].str.contains('e'))
print(df2['Name'].str.contains('b'))
# Out:
# 0     True
# 1    False
# 2     True
# Name: Name, dtype: bool
# 0    False
# 1     True
# 2    False
# Name: Name, dtype: bool

# %%
print(df2.shape)
print(df2.size)
print(df2.axes)
print(df2.ndim)
print(df2.dtypes)
print(df2.index)
print(df2.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['Name', 'Age', 'Year'], dtype='object')]
# 2
# Name     object
# Age     float64
# Year     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'Year'], dtype='object')
# [['Alexa' 10.0 '2000']
#  ['Bob' nan None]
#  ['Clarie' nan '2020']]

# %% [markdown]
# ##CONCATENATION

# %%
df6=pd.concat([df2,df2])
print(df6)
# Out:
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob   NaN  None
# 2  Clarie   NaN  2020
# 0   Alexa  10.0  2000
# 1     Bob   NaN  None
# 2  Clarie   NaN  2020

# %% [markdown]
# #Accessing DataFrame

# %%
df2['Name']
# Out:
# 0     Alexa
# 1       Bob
# 2    Clarie
# Name: Name, dtype: object

# %%
df2.Age
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df2.loc[0,'Name']
# Out:
# 'Alexa'

# %%
df2.iloc[0][0]
# Out:
# 'Alexa'

# %%
df2["Year"][1]='2023'
df2
# Out:
# <ipython-input-149-774b0605510a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Year"][1]='2023'
#      Name   Age  Year
# 0   Alexa  10.0  2000
# 1     Bob   NaN  2023
# 2  Clarie   NaN  2020

# %%
import pandas as pd
html=pd.read_html("https://en.wikipedia.org/wiki/Modern_Library_100_Best_Nonfiction")
html
# Out:
# [    #  Year                                              Title  \
#  0   1  1918                       The Education of Henry Adams
#  1   2  1902              The Varieties of Religious Experience
#  2   3  1901                                    Up From Slavery
#  3   4  1929                                A Room of One's Own
#  4   5  1962                                      Silent Spring
#  5   6  1932                         Selected Essays, 1917–1932
#  6   7  1968                                   The Double Helix
#  7   8  1951                                      Speak, Memory
#  8   9  1919                              The American Language
#  9  10  1936  The General Theory of Employment, Interest and...
#
#                   Author
#  0    Henry Brooks Adams
#  1         William James
#  2  Booker T. Washington
#  3        Virginia Woolf
#  4         Rachel Carson
#  5            T.S. Eliot
#  6       James D. Watson
#  7      Vladimir Nabokov
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['item_price']=df.item_price.str.replace('$','')
df
# Out:
# <ipython-input-32-732cf18ea28f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price']=df.item_price.str.replace('$','')
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
df['item_price']=df['item_price'].astype(float)
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df['item_price']=df['item_price']*2
#df

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df[df['item_price']<1.1]
print(df_drink)
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df[df['choice_description'].str.contains("Black Beans")].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df['item_price'] < 10) & (df['item_name'] == 'Chicken Bowl' )]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df['item_price'] < 10) & (df['item_name'] == 'Chicken Bowl' )].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
#d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/blob/master/pandas/imdb_1000.csv")
#https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
d
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
d[(d['star_rating'] > 9) & (d['content_rating'] == 'R')]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
d[(d['star_rating'] >= 9) & (d['genre'] == 'Action')]
# Out:
#    star_rating            title content_rating   genre  duration  \
# 3          9.0  The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
d[(d['star_rating'] <=8) & (d['content_rating'] == 'R')]
# Out:
#      star_rating                title content_rating      genre  duration  \
# 300          8.0             Dogville              R      Crime       178
# 306          8.0   This Is Spinal Tap              R     Comedy        82
# 308          8.0  Pink Floyd The Wall              R  Animation        95
# 309          8.0        Blood Diamond              R  Adventure       143
# 311          8.0  Slumdog Millionaire              R      Drama       120
# ..           ...                  ...            ...        ...       ...
# 968          7.4  The English Patient              R      Drama       162
# 969          7.4  Law Abiding Citizen              R      Crime       109
# 970          7.4          Wonder Boys              R      Drama       107
# 971          7.4   Death at a Funeral              R     Comedy        90
# 978          7.4          Wall Street              R      Crime       126
#
#                                            actors_list
# ...

# %%
d[(d['star_rating'] <=8) & (d['content_rating'] == 'R')].sort_values(['duration'])
# Out:
#      star_rating                              title content_rating      genre  \
# 742          7.6                          Following              R    Mystery
# 864          7.5                              [Rec]              R     Horror
# 533          7.8                       Run Lola Run              R     Action
# 541          7.8  South Park: Bigger Longer & Uncut              R  Animation
# 738          7.6                   Army of Darkness              R     Comedy
# ..           ...                                ...            ...        ...
# 611          7.7                         Short Cuts              R     Comedy
# 318          8.0                           Magnolia              R      Drama
# 316          8.0                                JFK              R      Drama
# 671          7.7                         Grindhouse              R     Action
# 424          7.9                    The Right Stuff              R  Adventure
#
# ...

# %%
d[d['actors_list'].str.contains('Tom Cruise')].sort_values(['star_rating','duration'])
# Out:
#      star_rating                                              title  \
# 797          7.6                                         Collateral
# 779          7.6  Interview with the Vampire: The Vampire Chroni...
# 716          7.6                                     A Few Good Men
# 686          7.7                                    Minority Report
# 613          7.7                                   The Last Samurai
# 391          8.0                                   Edge of Tomorrow
# 325          8.0                                           Rain Man
# 318          8.0                                           Magnolia
#
#     content_rating   genre  duration  \
# 797              R   Crime       120
# 779              R  Horror       123
# 716              R   Drama       138
# 686          PG-13  Action       145
# 613              R  Action       154
# 391          PG-13  Action       113
# 325              R   Drama       133
# 318              R   Drama       188
#
# ...

# %%
d[d['actors_list'].str.contains('Tom Cruise')].sort_values(['star_rating','duration'],ascending=[False,True])
# Out:
#      star_rating                                              title  \
# 716          7.6                                     A Few Good Men
# 779          7.6  Interview with the Vampire: The Vampire Chroni...
# 797          7.6                                         Collateral
# 613          7.7                                   The Last Samurai
# 686          7.7                                    Minority Report
# 318          8.0                                           Magnolia
# 325          8.0                                           Rain Man
# 391          8.0                                   Edge of Tomorrow
#
#     content_rating   genre  duration  \
# 716              R   Drama       138
# 779              R  Horror       123
# 797              R   Crime       120
# 613              R  Action       154
# 686          PG-13  Action       145
# 318              R   Drama       188
# 325              R   Drama       133
# 391          PG-13  Action       113
#
# ...

# %%
r=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
r
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
r.dropna(how="all")
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
r.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
r.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
r['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
r['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks[drinks['continent']=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks['continent']=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
